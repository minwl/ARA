# %%
import requests

url = "https://2f1d-34-81-3-72.ngrok-free.app/QA"

question = "What is Tesla's ~"
context = {"Hello this is context","Hello this is context2","Hello this is context3"}

response = requests.get(url, params={'input_text':question, 'ctx_text':'@@@'.join(context)})

print(response.text)
# Out:
# ["What is Tesla's ~",["Hello this is context2","Hello this is context","Hello this is context3"]]

# %%
# !pip install flask_ngrok
# !pip install pyngrok
import io
import json
from flask import Flask, jsonify, request
from flask_ngrok import run_with_ngrok
import requests
# !ngrok authtoken 2GMT9HIFXBhEnlDuHyHRqPef2cS_5wkjjrh4AKhnnMfJRJfT5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
app = Flask(__name__)
run_with_ngrok(app)
@app.route("/")
def index():
  return "<h1> Assistant of RA </h1>"

@app.route('/QA', methods=['GET'])
def QA():
    if request.method == 'GET':
        query= request.args.get('input_text')
        ctx = request.args.get('ctx_text')

        ctx_list = ctx.split("@@@")

        print(query)
        print(ctx_list)
        return [query,ctx_list]

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
#  * Running on http://619e-35-237-182-72.ngrok-free.app
#  * Traffic stats available on http://127.0.0.1:4040

# %%
proverbs = ["Don't put all your eggs in one basket.",
"Buy low, sell high.",
"Don't catch a falling knife.",
"Time in the market beats timing the market.",
"A rising tide lifts all boats.",
"Bulls make money, bears make money, pigs get slaughtered.",
"Don't fight the trend.",
"The market is a voting machine in the short term, a weighing machine in the long term.",
"The trend is your friend.",
"Cut your losses and let your profits run.",
"Buy on the rumor, sell on the news.",
"Greed is good, but too much of it can be dangerous.",
"Don't invest in something you don't understand.",
"The stock market is driven by fear and greed.",
"Investing should be boring.",
"Don't let emotions drive your investment decisions.",
"Patience is a virtue in the stock market.",
"Pigs get fat, hogs get slaughtered.",
"Don't try to time the market.",
"Don't invest more than you can afford to lose.",
"Buy quality, not just the cheapest stock.",
"Diversify your portfolio to manage risk.",
"Invest for the long term.",
"It's not about timing the market, it's about time in the market.",
"Don't chase hot stocks.",
"Invest in what you know.",
"Don't let a single bad investment ruin your portfolio.",
"Be fearful when others are greedy and greedy when others are fearful.",
"Don't invest based on tips from others.",
"The stock market is a marathon, not a sprint.",
"Don't let short-term market fluctuations discourage you.",
"Don't put your faith in a single stock.",
"Invest in companies with a competitive advantage.",
"Don't be swayed by market noise.",
"The market can remain irrational longer than you can stay solvent.",
"Don't invest with borrowed money.",
"Invest in companies with strong management teams.",
"Do your own research before investing.",
"Invest in assets, not liabilities.",
"Be prepared for market volatility.",
"Don't let fear or greed drive your investment decisions.",
"Investing is a marathon, not a sprint.",
"Don't mistake a bull market for genius.",
"Invest in companies with a moat.",
"Don't be afraid to take profits.",
"Invest in what you believe in.",
"Don't let short-term losses overshadow long-term gains.",
"Invest in companies with a track record of profitability.",
"Don't follow the crowd blindly.",
"Invest in companies with sustainable competitive advantages.",
"Don't let a single bad day in the market deter you.",
"Invest in companies with strong balance sheets.",
"Don't invest based on emotions.",
"Invest in companies with a clear growth strategy.",
"Don't try to time the market, focus on time in the market.",
"Invest in companies with a history of dividend payments.",
"Don't invest in something you don't understand.",
"Invest in companies with strong cash flow.",
"Don't be swayed by short-term market noise.",
"Invest in companies with a wide economic moat.",
"Don't let market volatility shake your confidence.",
"Invest in companies with a competitive edge."]

# %%
import requests
import time
import random
start = time.time()  # 시작 시간 저장
url = "https://e382-34-143-188-190.ngrok-free.app/QA"

question = "ms_energy; What is trends about exxon?"
idx = random.randrange(1,len(proverbs))
print(proverbs[idx])
response = requests.get(url, params={'input_text':question})

print(response.text)
print("time :", time.time() - start)
# Out:
# Don't catch a falling knife.
# Result: Positive   Sentiment Score: 0.4986248379403895 <br> <br>Evidence1. <br> Exxon Mobil Corporation (XOM) Is a Trending Stock: Facts to Know Before Betting on It
#
# Exxon Mobil (XOM) has been one of the most searched-for stocks on Zacks.com lately. So, you might want to look at some of the facts that could shape the stock's performance in the near term.
#
# Shares of this oil and natural gas company have returned -3.5% over the past month versus the Zacks S&P 500 composite's +3.6% change. The Zacks Oil and Gas - Integrated - International industry, to which Exxon belongs, has lost 2.8% over this period <br> Reference: https://finance.yahoo.com/news//news/exxon-mobil-corporation-xom-trending-130011307.html <br>Evidence2. <br> Occidental Petroleum (OXY) Gains As Market Dips: What You Should Know
#
# ...

# %%
response.text
# Out:
# '["the roles of chair of the board and CEO should not be held by the same individual","Norway wealth fund to vote against ExxonMobil CEO Woods as chair of the board\\n\\nOSLO, May 26 (Reuters) - Norway\'s $1.4 trillion sovereign wealth fund, the world\'s single largest stock market investor, said on Friday it would vote against CEO Darren W. Woods continuing as chair of the board at oil major ExxonMobil .\\n\\nThe fund based its decision on the principle that the roles of chair of the board and CEO should not be held by the same individual, it said on its website. (Reporting by Victoria Klesty, editing by Gwladys Fouche)"]\n'

# %%
proverbs = ["Don't put all your eggs in one basket.",
"Buy low, sell high.",
"Don't catch a falling knife.",
"Time in the market beats timing the market.",
"A rising tide lifts all boats.",
"Bulls make money, bears make money, pigs get slaughtered.",
"Don't fight the trend.",
"The market is a voting machine in the short term, a weighing machine in the long term.",
"The trend is your friend.",
"Cut your losses and let your profits run.",
"Buy on the rumor, sell on the news.",
"Greed is good, but too much of it can be dangerous.",
"Don't invest in something you don't understand.",
"The stock market is driven by fear and greed.",
"Investing should be boring.",
"Don't let emotions drive your investment decisions.",
"Patience is a virtue in the stock market.",
"Pigs get fat, hogs get slaughtered.",
"Don't try to time the market.",
"Don't invest more than you can afford to lose.",
"Buy quality, not just the cheapest stock.",
"Diversify your portfolio to manage risk.",
"Invest for the long term.",
"It's not about timing the market, it's about time in the market.",
"Don't chase hot stocks.",
"Invest in what you know.",
"Don't let a single bad investment ruin your portfolio.",
"Be fearful when others are greedy and greedy when others are fearful.",
"Don't invest based on tips from others.",
"The stock market is a marathon, not a sprint.",
"Don't let short-term market fluctuations discourage you.",
"Don't put your faith in a single stock.",
"Invest in companies with a competitive advantage.",
"Don't be swayed by market noise.",
"The market can remain irrational longer than you can stay solvent.",
"Don't invest with borrowed money.",
"Invest in companies with strong management teams.",
"Do your own research before investing.",
"Invest in assets, not liabilities.",
"Be prepared for market volatility.",
"Don't let fear or greed drive your investment decisions.",
"Investing is a marathon, not a sprint.",
"Don't mistake a bull market for genius.",
"Invest in companies with a moat.",
"Don't be afraid to take profits.",
"Invest in what you believe in.",
"Don't let short-term losses overshadow long-term gains.",
"Invest in companies with a track record of profitability.",
"Don't follow the crowd blindly.",
"Invest in companies with sustainable competitive advantages.",
"Don't let a single bad day in the market deter you.",
"Invest in companies with strong balance sheets.",
"Don't invest based on emotions.",
"Invest in companies with a clear growth strategy.",
"Don't try to time the market, focus on time in the market.",
"Invest in companies with a history of dividend payments.",
"Don't invest in something you don't understand.",
"Invest in companies with strong cash flow.",
"Don't be swayed by short-term market noise.",
"Invest in companies with a wide economic moat.",
"Don't let market volatility shake your confidence.",
"Invest in companies with a competitive edge."]

# %%
import random
random.randrange(1,len(proverbs))
# Out:
# 56
